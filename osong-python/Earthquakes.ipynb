# %% [markdown]
# # Earthquakes
#
# JSON Format [USGS data](https://earthquake.usgs.gov/earthquakes/feed/)

# %% [markdown]
# ## Yesterday (1/8/2024)

# %%
from pathlib import Path
import json

# 데이터를 문자열로 읽어 파이썬 객체로 변환합니다
path = Path(r'C:\Users\PC\Desktop\python\all_day.geojson')
contents = path.read_text(encoding = 'utf-8')
all_eq_data = json.loads(contents)

# 데이터 파일을 더 읽기 쉬운 형태로 바꿉니다
path = Path(r'C:\Users\PC\Desktop\python\all_day_readable.geojson')
readable_contents = json.dumps(all_eq_data, indent = 4)
path.write_text(readable_contents)
# Out:
# 323242

# %%
# 지진 몇개 있는지 확인
all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))
# Out:
# 232

# %%
# 마지막 10개 크기 확인
mags = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag'] # 크기
    mags.append(mag)
    
print(mags[:10]) # 마지막 10개 출력
# Out:
# [0.78, 2.4, 4.3, 4.2, 0.22, 4.5, 2.91, 4.9, 1.08, 2.2]

# %%
# 마지막 10개 크기와 위치와 타이틀 확인
mags, lons, lats, titles = [], [], [], []

for eq_dict in all_eq_dicts:
    mag = abs(eq_dict['properties']['mag']) # 크기
    lon = eq_dict['geometry']['coordinates'][0] # 경도
    lat = eq_dict['geometry']['coordinates'][1] # 위도
    t = eq_dict['properties']['title']
    
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    titles.append(t)
    
print(mags[:10]) # 마지막 10개 출력
print(lons[:10]) # 마지막 10개 출력
print(lats[:10]) # 마지막 10개 출력
print(titles[:10])
# Out:
# [0.78, 2.4, 4.3, 4.2, 0.22, 4.5, 2.91, 4.9, 1.08, 2.2]
# [-122.8351669, -147.5335, -129.9927, 70.8608, -122.8160019, 126.3377, -155.494, -79.655, -122.8044968, -150.9517]
# [38.8406677, 62.2612, 50.856, 36.5429, 38.8438339, 4.7302, 19.1755, -8.0809, 38.8204994, 62.9401]
# ['M 0.8 - 10 km NW of The Geysers, CA', 'M 2.4 - 40 km NNW of Eureka Roadhouse, Alaska', 'M 4.3 - 207 km W of Port McNeill, Canada', 'M 4.2 - 35 km S of Jurm, Afghanistan', 'M 0.2 - 8 km WNW of Cobb, CA', 'M 4.5 - 122 km SE of Sarangani, Philippines', 'M 2.9 - 3 km SSW of Pāhala, Hawaii', 'M 4.9 - 47 km WSW of Santiago de Cao, Peru', 'M 1.1 - 6 km NW of The Geysers, CA', 'M 2.2 - 50 km N of Petersville, Alaska']

# %%
import plotly.express as px

title = 'Global Earthquakes (1/8/2024)'

fig = px.scatter_geo(lat = lats, lon = lons, size = mags,
                     color = mags, color_continuous_scale = 'Viridis', 
                     labels = {
                         'color': '크기',
                         'lat': '위도',
                         'lon': '경도'
                     },
                     projection = 'natural earth',
                     hover_name = titles,
                     title = title)
fig.show()
# Out:
# <div>                            <div id="6cd936d0-ec0c-4d60-b0b1-2f5525d4d775" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd936d0-ec0c-4d60-b0b1-2f5525d4d775")) {                    Plotly.newPlot(                        "6cd936d0-ec0c-4d60-b0b1-2f5525d4d775",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>size=%{marker.size}<br>\uc704\ub3c4=%{lat}<br>\uacbd\ub3c4=%{lon}<br>\ud06c\uae30=%{marker.color}<extra></extra>","hovertext":["M 0.8 - 10 km NW of The Geysers, CA","M 2.4 - 40 km NNW of Eureka Roadhouse, Alaska","M 4.3 - 207 km W of Port McNeill, Canada","M 4.2 - 35 km S of Jurm, Afghanistan","M 0.2 - 8 km WNW of Cobb, CA","M 4.5 - 122 km SE of Sarangani, Philippines","M 2.9 - 3 km SSW of P\u0101hala, Hawaii","M 4.9 - 47 km WSW of Santiago de Cao, Peru","M 1.1 - 6 km NW of The Geysers, CA","M 2.2 - 50 km N of Petersville, Alaska","M 0.8 - 6 km W of Cobb, CA","M 1.1 - 11 km SSW of Willow, Alaska","M 1.4 - 56 km WSW of Tatitlek, Alaska","M 1.0 - 10 km WNW of The Geysers, CA","M 1.7 - 19 km W of Point MacKenzie, Alaska","M 0.4 - 6 km W of Cobb, CA","M 1.7 - 45 km NW of Toyah, Texas","M 1.8 - 62 km SE of Pope-Vannoy Landing, Alaska","M 1.9 - 19 km W of Point MacKenzie, Alaska","M 4.4 - 236 km WNW of Houma, Tonga","M 0.9 - 2 km NE of The Geysers, CA","M 0.3 - 8 km NW of The Geysers, CA","M 1.6 - 46 km NW of Toyah, Texas","M 1.7 - 54 km S of Whites City, New Mexico","M 2.2 - 2 km NNE of Tallaboa, Puerto Rico","M 1.5 - 82 km W of Karluk, Alaska","M 1.2 - 7 km NW of The Geysers, CA","M 1.9 - 39 km SE of Pope-Vannoy Landing, Alaska","M 2.0 - 7 km NNE of Big Bear City, CA","M 1.1 - 8 km NW of The Geysers, CA","M 0.0 - 39 km ENE of Beatty, Nevada","M 1.5 - 60 km S of Whites City, New Mexico","M 2.1 - 63 km NNE of Petersville, Alaska","M 2.2 - 13 km NNW of Meadow Lakes, Alaska","M 0.2 - 8 km NW of The Geysers, CA","M 2.0 - 52 km S of Whites City, New Mexico","M 4.6 - 101 km ENE of Finschhafen, Papua New Guinea","M 4.2 - 193 km ENE of Levuka, Fiji","M 0.8 - 14 km SE of Anza, CA","M 2.1 - 4 km W of Cobb, CA","M 0.7 - 0 km NE of The Geysers, CA","M 1.6 - 55 km SSW of Whites City, New Mexico","M 0.0 - 25 km W of Dutch Harbor, Alaska","M 0.5 - 4 km W of Cobb, CA","M 6.7 - 100 km SE of Sarangani, Philippines","M 1.7 - 45 km NW of Toyah, Texas","M 1.9 - 32 km NNE of Redway, CA","M 2.8 - 3 km WSW of Indios, Puerto Rico","M 1.6 - 31 km NNW of Valdez, Alaska","M 3.1 - 72 km N of Arecibo, Puerto Rico","M 1.4 - 13 km SE of Tehachapi, CA","M 1.7 - 4 km W of San Juan Bautista, CA","M -0.7 - 84 km NNW of Karluk, Alaska","M 0.7 - 2 km ENE of San Jacinto, CA","M 1.6 Quarry Blast - 5 km E of Butte, Montana","M 1.5 Quarry Blast - 5 km N of Boron, CA","M 0.2 - 85 km NW of Karluk, Alaska","M 4.2 - 28 km SSE of Pakokku, Myanmar","M 1.3 - 89 km NW of Karluk, Alaska","M 2.6 - 11 km NNE of Houston, Alaska","M 1.8 - 36 km NNW of Beluga, Alaska","M 4.4 - 104 km NNE of B\u0101fq, Iran","M 1.7 - 46 km NW of Toyah, Texas","M 1.4 - 14 km S of Fern Forest, Hawaii","M 0.9 - 9 km WNW of The Geysers, CA","M 2.0 - 9 km NW of The Geysers, CA","M 1.3 - 8 km W of Cobb, CA","M 0.4 - 27 km N of Ivanof Bay, Alaska","M 0.8 - 10 km NNE of Ashford, Washington","M 2.1 - 42 km NW of Toyah, Texas","M 1.2 - 2 km NNE of The Geysers, CA","M 1.9 - 7 km SE of Elgin, South Carolina","M 1.5 - 10 km NE of Ocotillo Wells, CA","M 2.2 - 53 km NW of Toyah, Texas","M 1.8 - 11 km ENE of P\u0101hala, Hawaii","M 2.2 - 11 km WSW of Puebla, B.C., MX","M 4.6 - 45 km S of Dushanzi, China","M 1.5 - 65 km NNE of Van Horn, Texas","M 0.0 - 6 km ENE of Hebgen Lake Estates, Montana","M 1.7 - 45 km NW of Toyah, Texas","M 2.2 - 6 km E of Hebgen Lake Estates, Montana","M 1.1 - 2 km NNW of The Geysers, CA","M 1.5 - 16 km W of Searles Val ...

# %% [markdown]
# ## All Month (12/8/2023 - 1/8/2024)

# %%
from pathlib import Path
import json

# 데이터를 문자열로 읽어 파이썬 객체로 변환합니다
path = Path(r'C:\Users\PC\Desktop\python\all_month.geojson')
contents = path.read_text(encoding = 'utf-8')
all_eq_data = json.loads(contents)

# 데이터 파일을 더 읽기 쉬운 형태로 바꿉니다
path = Path(r'C:\Users\PC\Desktop\python\all_month_readable.geojson')
readable_contents = json.dumps(all_eq_data, indent = 4)
path.write_text(readable_contents)
# Out:
# 12920745

# %%
# 지진 몇개 있는지 확인
all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))
# Out:
# 9282

# %%
# 마지막 10개 크기 확인
mags = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag'] # 크기
    mags.append(mag)
    
print(mags[:10]) # 마지막 10개 출력
# Out:
# [0.83, 5.4, 0.8, 0.77, 1.26, 2.4, 0.78, 2.4, 4.3, 4.2]

# %%
# 마지막 10개 크기와 위치와 타이틀 확인
mags, lons, lats, titles = [], [], [], []

for eq_dict in all_eq_dicts:
    if eq_dict['properties']['mag'] is None:
        continue
        
    mag = abs(eq_dict['properties']['mag']) # 크기
    lon = eq_dict['geometry']['coordinates'][0] # 경도
    lat = eq_dict['geometry']['coordinates'][1] # 위도
    t = eq_dict['properties']['title']
    
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    titles.append(t)
    
print(mags[:10]) # 마지막 10개 출력
print(lons[:10]) # 마지막 10개 출력
print(lats[:10]) # 마지막 10개 출력
print(titles[:10])
# Out:
# [0.83, 5.4, 0.8, 0.77, 1.26, 2.4, 0.78, 2.4, 4.3, 4.2]
# [-122.8359985, 167.2447, -116.3897, -122.8161697, -117.7911667, -150.2993, -122.8351669, -147.5335, -129.9927, 70.8608]
# [38.8388329, -14.0452, 37.1229, 38.833168, 33.9943333, 61.3585, 38.8406677, 62.2612, 50.856, 36.5429]
# ['M 0.8 - 10 km NW of The Geysers, CA', 'M 5.4 - 38 km WSW of Sola, Vanuatu', 'M 0.8 - 40 km NE of Beatty, Nevada', 'M 0.8 - 8 km NW of The Geysers, CA', 'M 1.3 - 3 km W of Chino Hills, CA', 'M 2.4 - 17 km W of Point MacKenzie, Alaska', 'M 0.8 - 10 km NW of The Geysers, CA', 'M 2.4 - 40 km NNW of Eureka Roadhouse, Alaska', 'M 4.3 - 207 km W of Port McNeill, Canada', 'M 4.2 - 35 km S of Jurm, Afghanistan']

# %%
import plotly.express as px

title = 'Global Earthquakes (12/8/2023 - 1/8/2024)'

fig = px.scatter_geo(lat = lats, lon = lons, size = mags,
                     color = mags, color_continuous_scale = 'Viridis', 
                     labels = {
                         'color': '크기',
                         'lat': '위도',
                         'lon': '경도'
                     },
                     projection = 'natural earth',
                     hover_name = titles,
                     title = title)
fig.show()
# Out:
# <div>                            <div id="736e61ba-2067-4a7b-ba0b-da60c90e08ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("736e61ba-2067-4a7b-ba0b-da60c90e08ec")) {                    Plotly.newPlot(                        "736e61ba-2067-4a7b-ba0b-da60c90e08ec",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>size=%{marker.size}<br>\uc704\ub3c4=%{lat}<br>\uacbd\ub3c4=%{lon}<br>\ud06c\uae30=%{marker.color}<extra></extra>","hovertext":["M 0.8 - 10 km NW of The Geysers, CA","M 5.4 - 38 km WSW of Sola, Vanuatu","M 0.8 - 40 km NE of Beatty, Nevada","M 0.8 - 8 km NW of The Geysers, CA","M 1.3 - 3 km W of Chino Hills, CA","M 2.4 - 17 km W of Point MacKenzie, Alaska","M 0.8 - 10 km NW of The Geysers, CA","M 2.4 - 40 km NNW of Eureka Roadhouse, Alaska","M 4.3 - 207 km W of Port McNeill, Canada","M 4.2 - 35 km S of Jurm, Afghanistan","M 0.2 - 8 km WNW of Cobb, CA","M 4.5 - 122 km SE of Sarangani, Philippines","M 2.9 - 3 km SSW of P\u0101hala, Hawaii","M 4.9 - 47 km WSW of Santiago de Cao, Peru","M 1.1 - 6 km NW of The Geysers, CA","M 2.2 - 50 km N of Petersville, Alaska","M 0.8 - 6 km W of Cobb, CA","M 1.1 - 11 km SSW of Willow, Alaska","M 1.4 - 56 km WSW of Tatitlek, Alaska","M 1.0 - 10 km WNW of The Geysers, CA","M 1.7 - 19 km W of Point MacKenzie, Alaska","M 0.4 - 6 km W of Cobb, CA","M 1.7 - 45 km NW of Toyah, Texas","M 1.8 - 62 km SE of Pope-Vannoy Landing, Alaska","M 1.9 - 19 km W of Point MacKenzie, Alaska","M 4.4 - 236 km WNW of Houma, Tonga","M 0.9 - 2 km NE of The Geysers, CA","M 0.3 - 8 km NW of The Geysers, CA","M 1.6 - 46 km NW of Toyah, Texas","M 1.7 - 54 km S of Whites City, New Mexico","M 2.2 - 2 km NNE of Tallaboa, Puerto Rico","M 1.5 - 82 km W of Karluk, Alaska","M 1.2 - 7 km NW of The Geysers, CA","M 1.9 - 39 km SE of Pope-Vannoy Landing, Alaska","M 2.0 - 7 km NNE of Big Bear City, CA","M 1.1 - 8 km NW of The Geysers, CA","M 0.0 - 39 km ENE of Beatty, Nevada","M 1.5 - 60 km S of Whites City, New Mexico","M 2.1 - 63 km NNE of Petersville, Alaska","M 2.2 - 13 km NNW of Meadow Lakes, Alaska","M 0.2 - 8 km NW of The Geysers, CA","M 2.0 - 52 km S of Whites City, New Mexico","M 4.6 - 101 km ENE of Finschhafen, Papua New Guinea","M 4.2 - 193 km ENE of Levuka, Fiji","M 0.8 - 14 km SE of Anza, CA","M 2.1 - 4 km W of Cobb, CA","M 0.7 - 0 km NE of The Geysers, CA","M 1.6 - 55 km SSW of Whites City, New Mexico","M 0.0 - 25 km W of Dutch Harbor, Alaska","M 0.5 - 4 km W of Cobb, CA","M 6.7 - 100 km SE of Sarangani, Philippines","M 1.7 - 45 km NW of Toyah, Texas","M 1.9 - 32 km NNE of Redway, CA","M 2.8 - 3 km WSW of Indios, Puerto Rico","M 1.6 - 31 km NNW of Valdez, Alaska","M 3.1 - 72 km N of Arecibo, Puerto Rico","M 1.4 - 13 km SE of Tehachapi, CA","M 1.7 - 4 km W of San Juan Bautista, CA","M -0.7 - 84 km NNW of Karluk, Alaska","M 0.7 - 2 km ENE of San Jacinto, CA","M 1.6 Quarry Blast - 5 km E of Butte, Montana","M 1.5 Quarry Blast - 5 km N of Boron, CA","M 0.2 - 85 km NW of Karluk, Alaska","M 4.2 - 28 km SSE of Pakokku, Myanmar","M 1.3 - 89 km NW of Karluk, Alaska","M 2.6 - 11 km NNE of Houston, Alaska","M 1.8 - 36 km NNW of Beluga, Alaska","M 4.4 - 104 km NNE of B\u0101fq, Iran","M 1.7 - 46 km NW of Toyah, Texas","M 1.4 - 14 km S of Fern Forest, Hawaii","M 0.9 - 9 km WNW of The Geysers, CA","M 2.0 - 9 km NW of The Geysers, CA","M 1.3 - 8 km W of Cobb, CA","M 0.4 - 27 km N of Ivanof Bay, Alaska","M 0.8 - 10 km NNE of Ashford, Washington","M 2.1 - 42 km NW of Toyah, Texas","M 1.2 - 2 km NNE of The Geysers, CA","M 1.9 - 7 km SE of Elgin, South Carolina","M 1.5 - 10 km NE of Ocotillo Wells, CA","M 2.2 - 53 km NW of Toyah, Texas","M 1.8 - 11 km ENE of P\u0101hala, Hawaii","M 2.2 - 11 km WSW of Puebla, B.C., MX","M 4.6 - 45 km S of Dushanzi, China","M 1.5 - 65 k ...
